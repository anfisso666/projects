# %% [markdown]
# # Гляним на  наш опрос

# %%
import pandas as pd
import numpy as np
import altair as alt

# %%
df_origin = pd.read_excel('f/ИССЛЕДОВАНИЕ ПОВЕДЕНИЯ (Ответы).xlsx')

# %% [markdown]
# ###  Общий объем

# %%
df_origin.shape
# Out:
# (99, 12)

# %%
# переименовываем столбцы 
df_origin.rename(columns = {'Отметка времени': 'Дата', 'Выберете пол': 'Пол', 'Женат / замужем': 'Семья',
                    'Укажите ваш возраст': 'Возраст','Есть ли у вас дети?': 'Дети', 
                     'Выберете сферу вашей деятельности': 'Деятельность', 
                     'Оцените, как часто вы пользуетесь  социальными сетями?\nОтветы даются по пятибалльной шкале:\n1 – очень редко\n2 – иногда\n3 – часто\n4 – очень часто\n5 – практически не выхожу': 'Частота использования',
                     'Перейдёте по ссылке по рекомендации друзей/знакомых?': 'Переход по ссылке', 
                     'Сделаете репост по просьбе друзей/знакомых?': 'Репост по просьбе', 'Какие чувства вызовет такая реклама услуг?': 'Что вызывает реклама услуг', 'Какие чувства вызовет просьба сделать репост?': 'Чувства от просьбы'
                    }, inplace = True )

# %%
df_origin.insert(1, "День месяца", df_origin['Дата'].dt.day)

# %%
df_origin.sample(3)
# Out:
#                       Дата  День месяца      Пол  Возраст Семья Дети  \
# 83 2023-03-15 14:57:12.528           15  Мужской       19   Нет  Нет
# 47 2023-03-13 09:25:51.452           13  Женский       31   Нет  Нет
# 96 2023-03-19 11:12:08.251           19  Мужской       36    Да   Да
#
#    Высшее образование                        Деятельность  \
# 83                Нет                          Не работаю
# 47                 Да  Маркетинговые, рекламные агентства
# 96                 Да       IT, телеком, диджитал-сервисы
#
#     Частота использования Переход по ссылке Репост по просьбе  \
# 83                      2                Да               Нет
# 47                      4                Да               Нет
# 96                      2               Нет               Нет
#
#    Что вызывает реклама услуг Чувства от просьбы
# 83                      страх             любовь
# 47                    Интерес         Равнодушие
# 96                 Равнодушие         Равнодушие

# %% [markdown]
# ### динамика ответов по дням

# %%
df_origin.groupby('День месяца').agg({'Пол': 'count'})
# Out:
#              Пол
# День месяца
# 10            12
# 11            18
# 12            13
# 13            23
# 14            15
# 15             4
# 16             6
# 17             4
# 18             1
# 19             1
# 20             1
# 21             1

# %%
alt.Chart(df_origin).mark_bar().encode(
    x = alt.X('День месяца:T', bin = alt.BinParams(maxbins = 30)),
    y = 'count()',
    color=alt.Color('Пол', scale=alt.Scale(range=['#2A41B6', '#C5002F']))
).properties(   
   title='title',
   background='#FFFFF6',
   height=590, width=777 # coотношениe 1/3
).interactive()
# Out:
# alt.Chart(...)

# %% [markdown]
# <div style='background: #C5E8EF; taxt-align: center; width: 444px; margin: auto; padding:44px; border: 1px solid #636363'>
#     <h5 style='color: #476285;  text-align:center; margin: auto'>
#          Ждём чуда сверху, продолжаем.
#     </h5>
# </div>
