# %%
import pandas as pd

# %%
df = pd.read_excel('folder/2017 наценка.xlsx', header=None, skiprows=2)
# df.columns = ['']

# %%
# Столбцы с датой и АЗС – Заменяем nan значениями выше 
df[[3, 4]] = df[[3, 4]].fillna(method='ffill')
df[:4]
# Out:
#                                            0   \
# 0   Чек ККМ ГС00-000027 от 21.09.2017 9:57:48
# 1             ИВ Лимонад Лаймони 0,6 л стекло
# 2  Чек ККМ ГС00-000037 от 21.09.2017 11:10:32
# 3              Вода Волна Байкала 0,5 л негаз
#
#                                 1    2                    3   \
# 0                              NaN  5.0   21.09.2017 9:57:48
# 1  ВКУСОВАЯ, СЛАДКАЯ ВОДА, НАПИТКИ  NaN   21.09.2017 9:57:48
# 2                              NaN  6.0  21.09.2017 11:10:32
# 3                       БЕЛАЯ ВОДА  NaN  21.09.2017 11:10:32
#
#                               4   5      6   7      8      9      10
# 0  АЗС № 1 Героев Сталинграда 8А   1  48.30  70  21.70  44.93  31.00
# 1  АЗС № 1 Героев Сталинграда 8А   1  48.30  70  21.70  44.93  31.00
# 2  АЗС № 1 Героев Сталинграда 8А   1  26.57  40  13.43  50.55  33.58
# 3  АЗС № 1 Героев Сталинграда 8А   1  26.57  40  13.43  50.55  33.58

# %%
# Удаляем все строки с чеком 
df = df[~df[0].str.contains('Чек')]

# %%
df[:12]
# Out:
#                                    0                                1    2   \
# 1     ИВ Лимонад Лаймони 0,6 л стекло  ВКУСОВАЯ, СЛАДКАЯ ВОДА, НАПИТКИ  NaN
# 3      Вода Волна Байкала 0,5 л негаз                       БЕЛАЯ ВОДА  NaN
# 5      Вода Волна Байкала 0,5 л негаз                       БЕЛАЯ ВОДА  7.0
# 6        Вода Крым Аква 1,5 л газ ПЭТ                       БЕЛАЯ ВОДА  7.0
# 7      Вода Крым Аква 1,5 л негаз ПЭТ                       БЕЛАЯ ВОДА  7.0
# 8     ИВ Лимонад Лаймони 0,6 л стекло  ВКУСОВАЯ, СЛАДКАЯ ВОДА, НАПИТКИ  7.0
# 9          Лимонад Лаймони 1 л стекло  ВКУСОВАЯ, СЛАДКАЯ ВОДА, НАПИТКИ  7.0
# 10               Пепси Кола 0,33л ж/б  ВКУСОВАЯ, СЛАДКАЯ ВОДА, НАПИТКИ  7.0
# 11               Пепси кола 0,6 л пэт  ВКУСОВАЯ, СЛАДКАЯ ВОДА, НАПИТКИ  7.0
# 12              Пепси кола 1,25 л пэт  ВКУСОВАЯ, СЛАДКАЯ ВОДА, НАПИТКИ  7.0
# 13     Энерг.нап. Ягуар Фри 0,5 л ж/б           ЭНЕРГЕТИЧЕСКИЕ НАПИТКИ  7.0
# ...
